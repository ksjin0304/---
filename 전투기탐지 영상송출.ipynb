# %%
# !pip install ultralytics

# %%
import ultralytics
from ultralytics import YOLO

# %%
# Create a YOLOv8 model
model = YOLO('/content/drive/MyDrive/전투기탐지결과2/train/weights/best.pt')

# %%
model.predict('/content/drive/MyDrive/F35.mp4', save=True)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
model.predict('/content/drive/MyDrive/j20.mp4', save=True)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/580) /content/drive/MyDrive/j20.mp4: 640x480 1 C5, 10.6ms
# video 1/1 (2/580) /content/drive/MyDrive/j20.mp4: 640x480 1 C5, 8.1ms
# video 1/1 (3/580) /content/drive/MyDrive/j20.mp4: 640x480 1 C5, 7.6ms
# video 1/1 (4/580) /content/drive/MyDrive/j20.mp4: 640x480 1 C5, 7.7ms
# video 1/1 (5/580) /content/drive/MyDrive/j20.mp4: 640x480 1 C5, 7.6ms
# video 1/1 (6/580) /content/drive/MyDrive/j20.mp4: 640x480 1 C5, 7.6ms
# ...
